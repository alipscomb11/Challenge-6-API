# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
print(weather_api_key)
# Out:
# 3cd48a9163a47010816ddef4c58fde19

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 593

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?q=Singapore&appid=3cd48a9163a47010816ddef4c58fde19"

# Define an empty list to fetch the weather data for each city

city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid=3cd48a9163a47010816ddef4c58fde19"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tiksi
# Processing Record 2 of Set 1 | adamstown
# Processing Record 3 of Set 1 | sonamukhi
# Processing Record 4 of Set 1 | grytviken
# Processing Record 5 of Set 1 | isafjordur
# Processing Record 6 of Set 1 | senatobia
# Processing Record 7 of Set 1 | porto novo
# Processing Record 8 of Set 1 | kalajoki
# Processing Record 9 of Set 1 | papatowai
# Processing Record 10 of Set 1 | coruripe
# Processing Record 11 of Set 1 | sapele
# Processing Record 12 of Set 1 | ancud
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | port-aux-francais
# Processing Record 15 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 16 of Set 1 | puerto natales
# Processing Record 17 of Set 1 | oyama
# Processing Record 18 of Set 1 | saipan
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | georgetown
# Processing Record 21 of Set 1 | fortuna
# Processing Record 22 of Set 1 | santa marta de ortigueira
# Processing Record 23 of Set 1 | marsh harbour
# Processing Record 24 of Set 1 | ganye
# Processing Record 25 of Set 1 | happy valley-goose bay
# Processing Record 26 of Set 1 | wailua homesteads
# Processing Record 27 of Set 1 | tazacorte
# Processing Record 28 of Set 1 | cabo san lucas
# Processing Record 29 of Set 1 | mandera
# Processing Record 30 of Set 1 | st. john's
# Processing Record 31 of Set 1 | blackmans bay
# Processing Record 32 of Set 1 | bamboo flat
# Processing Record 33 of Set 1 | pozanti
# Processing Record 34 of Set 1 | afaahiti
# Processing Record 35 of Set 1 | yagry
# City not found. Skipping...
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | waitangi
# Processing Record 38 of Set 1 | kirovskiy
# Processing Record 39 of Set 1 | alaghsas
# Processing Record 40 of Set 1 | sitka
# Processing Record 41 of Set 1 | olonkinbyen
# Processing Record 42 of Set 1 | priozersk
# Processing Record 43 of Set 1 | walvis bay
# Processing Record 44 of Set 1 | cargados carajos
# City not found. Skipping...
# Processing Record 45 of Set 1 | uruzgan
# Processing Record 46 of Set 1 | holualoa
# Processing Record 47 of Set 1 | saudarkrokur
# Processing Record 48 of Set 1 | yellowknife
# Processing Record 49 of Set 1 | clane
# Processing Record 50 of Set 1 | tazovsky
# Processing Record 0 of Set 2 | suchiapa
# Processing Record 1 of Set 2 | sona
# Processing Record 2 of Set 2 | jose mariano jimenez
# City not found. Skipping...
# Processing Record 3 of Set 2 | necochea
# Processing Record 4 of Set 2 | tevriz
# Processing Record 5 of Set 2 | mangrol
# Processing Record 6 of Set 2 | new kingman-butler
# Processing Record 7 of Set 2 | bilibino
# Processing Record 8 of Set 2 | keflavik
# Processing Record 9 of Set 2 | cidreira
# Processing Record 10 of Set 2 | tirumullaivasal
# Processing Record 11 of Set 2 | laguna
# Processing Record 12 of Set 2 | port arthur
# Processing Record 13 of Set 2 | ust-nera
# Processing Record 14 of Set 2 | puerto aysen
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | kourou
# Processing Record 17 of Set 2 | saint-philippe
# Processing Record 18 of Set 2 | huntsville
# Processing Record 19 of Set 2 | port mathurin
# Processing Record 20 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 21 of Set 2 | hammerfest
# Processing Record 22 of Set 2 | khandyga
# Processing Record 23 of Set 2 | egilsstadir
# Processing Record 24 of Set 2 | iqaluit
# Processing Record 25 of Set 2 | weno
# Processing Record 26 of Set 2 | hawaiian paradise park
# Processing Record 27 of Set 2 | iskateley
# Processing Record 28 of Set 2 | uyuni
# Processing Record 29 of Set 2 | port elizabeth
# Processing Record 30 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 31 of Set 2 | new norfolk
# Processing Record 32 of Set 2 | whitehorse
# Processing Record 33 of Set 2 | puerto ayora
# Processing Record 34 of Set 2 | amga
# Processing Record 35 of Set 2 | yatou
# Processing Record 36 of Set 2 | kataragama
# City not found. Skipping...
# Processing Record 37 of Set 2 | susuman
# Processing Record 38 of Set 2 | minas de marcona
# Processing Record 39 of Set 2 | atafu village
# Processing Record 40 of Set 2 | gebeit
# Processing Record 41 of Set 2 | cannonvale
# Processing Record 42 of Set 2 | edinburgh of the seven seas
# Processing Record 43 of Set 2 | palikir - national government center
# Processing Record 44 of Set 2 | soacha
# Processing Record 45 of Set 2 | vredenburg
# City not found. Skipping...
# Processing Record 46 of Set 2 | barka'
# City not found. Skipping...
# Processing Record 47 of Set 2 | la romana
# Processing Record 48 of Set 2 | udachny
# Processing Record 49 of Set 2 | skelleftea
# Processing Record 0 of Set 3 | yinchuan
# Processing Record 1 of Set 3 | berdigestyakh
# Processing Record 2 of Set 3 | san fernando
# Processing Record 3 of Set 3 | college
# Processing Record 4 of Set 3 | hamilton
# Processing Record 5 of Set 3 | sarikei
# Processing Record 6 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 7 of Set 3 | west island
# Processing Record 8 of Set 3 | saint-pierre
# Processing Record 9 of Set 3 | harper
# Processing Record 10 of Set 3 | nar'yan-mar
# Processing Record 11 of Set 3 | ilulissat
# Processing Record 12 of Set 3 | alagoinha
# Processing Record 13 of Set 3 | chimore
# Processing Record 14 of Set 3 | aasiaat
# Processing Record 15 of Set 3 | enewetak
# Processing Record 16 of Set 3 | nabagram
# Processing Record 17 of Set 3 | tofol
# Processing Record 18 of Set 3 | naama
# Processing Record 19 of Set 3 | cabedelo
# Processing Record 20 of Set 3 | margate
# Processing Record 21 of Set 3 | avarua
# Processing Record 22 of Set 3 | tura
# Processing Record 23 of Set 3 | dubbo
# Processing Record 24 of Set 3 | ribeira grande
# Processing Record 25 of Set 3 | flying fish cove
# Processing Record 26 of Set 3 | margaret river
# Processing Record 27 of Set 3 | hounde
# Processing Record 28 of Set 3 | bethel
# Processing Record 29 of Set 3 | nev'yansk
# Processing Record 30 of Set 3 | gaiman
# Processing Record 31 of Set 3 | vorgashor
# Processing Record 32 of Set 3 | la junta
# Processing Record 33 of Set 3 | barra de santo antonio
# Processing Record 34 of Set 3 | invercargill
# Processing Record 35 of Set 3 | nova sintra
# Processing Record 36 of Set 3 | taltal
# Processing Record 37 of Set 3 | novyy urengoy
# Processing Record 38 of Set 3 | touros
# Processing Record 39 of Set 3 | toga village
# City not found. Skipping...
# Processing Record 40 of Set 3 | hithadhoo
# Processing Record 41 of Set 3 | stanley
# Processing Record 42 of Set 3 | choibalsan
# Processing Record 43 of Set 3 | katsuura
# Processing Record 44 of Set 3 | wa
# City not found. Skipping...
# Processing Record 45 of Set 3 | acarau
# Processing Record 46 of Set 3 | rongelap
# Processing Record 47 of Set 3 | tanki leendert
# City not found. Skipping...
# Processing Record 48 of Set 3 | mersing
# Processing Record 49 of Set 3 | broken hill
# Processing Record 0 of Set 4 | aibak
# Processing Record 1 of Set 4 | rikaze
# Processing Record 2 of Set 4 | n'diareme limamoulaye
# City not found. Skipping...
# Processing Record 3 of Set 4 | falkenberg
# Processing Record 4 of Set 4 | padam
# City not found. Skipping...
# Processing Record 5 of Set 4 | bayanaul
# Processing Record 6 of Set 4 | haiku-pauwela
# Processing Record 7 of Set 4 | gaspe
# Processing Record 8 of Set 4 | portland
# Processing Record 9 of Set 4 | luwuk
# Processing Record 10 of Set 4 | staraya kulatka
# Processing Record 11 of Set 4 | vilyuchinsk
# Processing Record 12 of Set 4 | graaff-reinet
# Processing Record 13 of Set 4 | preston
# Processing Record 14 of Set 4 | nikolayevsk-on-amure
# Processing Record 15 of Set 4 | nagqu
# Processing Record 16 of Set 4 | forster
# Processing Record 17 of Set 4 | swakopmund
# Processing Record 18 of Set 4 | anadyr
# Processing Record 19 of Set 4 | utrik
# Processing Record 20 of Set 4 | sandnessjoen
# Processing Record 21 of Set 4 | nova xavantina
# Processing Record 22 of Set 4 | kapuskasing
# Processing Record 23 of Set 4 | badger
# Processing Record 24 of Set 4 | nsanje
# Processing Record 25 of Set 4 | volosovo
# Processing Record 26 of Set 4 | madimba
# Processing Record 27 of Set 4 | hayma'
# City not found. Skipping...
# Processing Record 28 of Set 4 | galliano
# Processing Record 29 of Set 4 | andorra
# Processing Record 30 of Set 4 | satupa'itea
# City not found. Skipping...
# Processing Record 31 of Set 4 | port glaud
# City not found. Skipping...
# Processing Record 32 of Set 4 | qaqortoq
# Processing Record 33 of Set 4 | inhambane
# Processing Record 34 of Set 4 | bubaque
# Processing Record 35 of Set 4 | sabang
# Processing Record 36 of Set 4 | tolstoy-yurt
# Processing Record 37 of Set 4 | kailua-kona
# Processing Record 38 of Set 4 | nelson bay
# Processing Record 39 of Set 4 | keren
# Processing Record 40 of Set 4 | kil'mez'
# City not found. Skipping...
# Processing Record 41 of Set 4 | bichura
# Processing Record 42 of Set 4 | jiujiang
# Processing Record 43 of Set 4 | benguela
# Processing Record 44 of Set 4 | wenling
# Processing Record 45 of Set 4 | bredasdorp
# Processing Record 46 of Set 4 | east london
# Processing Record 47 of Set 4 | sassandra
# Processing Record 48 of Set 4 | kodiak
# Processing Record 49 of Set 4 | klyuchi
# Processing Record 0 of Set 5 | sinabang
# Processing Record 1 of Set 5 | thompson
# Processing Record 2 of Set 5 | lompoc
# Processing Record 3 of Set 5 | yambio
# Processing Record 4 of Set 5 | constantia
# Processing Record 5 of Set 5 | taquarana
# Processing Record 6 of Set 5 | papao
# Processing Record 7 of Set 5 | norilsk
# Processing Record 8 of Set 5 | hermanus
# Processing Record 9 of Set 5 | chonchi
# Processing Record 10 of Set 5 | arboletes
# Processing Record 11 of Set 5 | mount pearl
# Processing Record 12 of Set 5 | kingston
# Processing Record 13 of Set 5 | at taj
# Processing Record 14 of Set 5 | tralee
# Processing Record 15 of Set 5 | chos malal
# Processing Record 16 of Set 5 | kenai
# Processing Record 17 of Set 5 | arendal
# Processing Record 18 of Set 5 | camarinas
# Processing Record 19 of Set 5 | san patricio
# Processing Record 20 of Set 5 | naze
# Processing Record 21 of Set 5 | buala
# Processing Record 22 of Set 5 | kerikeri
# Processing Record 23 of Set 5 | praia da vitoria
# Processing Record 24 of Set 5 | gadzhiyevo
# Processing Record 25 of Set 5 | san matias
# Processing Record 26 of Set 5 | houghton
# Processing Record 27 of Set 5 | gunjur
# Processing Record 28 of Set 5 | nakamura
# Processing Record 29 of Set 5 | namibe
# Processing Record 30 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 31 of Set 5 | dudinka
# Processing Record 32 of Set 5 | arraial do cabo
# Processing Record 33 of Set 5 | dayr al 'asafir
# City not found. Skipping...
# Processing Record 34 of Set 5 | asau village
# City not found. Skipping...
# Processing Record 35 of Set 5 | codrington
# Processing Record 36 of Set 5 | dunedin
# Processing Record 37 of Set 5 | tan-tan
# Processing Record 38 of Set 5 | inverell
# Processing Record 39 of Set 5 | nouadhibou
# Processing Record 40 of Set 5 | revda
# Processing Record 41 of Set 5 | alice springs
# Processing Record 42 of Set 5 | talnakh
# Processing Record 43 of Set 5 | kalach
# Processing Record 44 of Set 5 | dingcheng
# Processing Record 45 of Set 5 | laurel
# Processing Record 46 of Set 5 | ananindeua
# Processing Record 47 of Set 5 | san felice circeo
# Processing Record 48 of Set 5 | mokhsogollokh
# Processing Record 49 of Set 5 | longyearbyen
# Processing Record 0 of Set 6 | san antonio de pale
# Processing Record 1 of Set 6 | darwin
# Processing Record 2 of Set 6 | lityn
# Processing Record 3 of Set 6 | akjoujt
# Processing Record 4 of Set 6 | alofi
# Processing Record 5 of Set 6 | sao jose de piranhas
# Processing Record 6 of Set 6 | uturoa
# Processing Record 7 of Set 6 | aginskoye
# Processing Record 8 of Set 6 | kasongo-lunda
# Processing Record 9 of Set 6 | ghat
# Processing Record 10 of Set 6 | nogliki
# Processing Record 11 of Set 6 | north battleford
# Processing Record 12 of Set 6 | san pedro
# Processing Record 13 of Set 6 | wotje
# Processing Record 14 of Set 6 | mount gambier
# Processing Record 15 of Set 6 | pamandzi
# Processing Record 16 of Set 6 | puerto madryn
# Processing Record 17 of Set 6 | natal
# Processing Record 18 of Set 6 | manismata
# Processing Record 19 of Set 6 | abraham's bay
# City not found. Skipping...
# Processing Record 20 of Set 6 | tshikapa
# Processing Record 21 of Set 6 | lanxi
# Processing Record 22 of Set 6 | loch garman
# Processing Record 23 of Set 6 | nemuro
# Processing Record 24 of Set 6 | lerwick
# Processing Record 25 of Set 6 | sonsorol village
# City not found. Skipping...
# Processing Record 26 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 27 of Set 6 | duncan town
# City not found. Skipping...
# Processing Record 28 of Set 6 | hadibu
# Processing Record 29 of Set 6 | la passe
# Processing Record 30 of Set 6 | eyl
# Processing Record 31 of Set 6 | zambezi
# Processing Record 32 of Set 6 | konarka
# Processing Record 33 of Set 6 | novodvinsk
# Processing Record 34 of Set 6 | quellon
# Processing Record 35 of Set 6 | bikenibeu village
# Processing Record 36 of Set 6 | castillos
# Processing Record 37 of Set 6 | kem'
# Processing Record 38 of Set 6 | makhambet
# Processing Record 39 of Set 6 | palmer
# Processing Record 40 of Set 6 | fada
# Processing Record 41 of Set 6 | taungdwingyi
# Processing Record 42 of Set 6 | sanya
# Processing Record 43 of Set 6 | al mindak
# Processing Record 44 of Set 6 | boende
# Processing Record 45 of Set 6 | colonia
# Processing Record 46 of Set 6 | usinsk
# Processing Record 47 of Set 6 | taoudenni
# Processing Record 48 of Set 6 | nizhneangarsk
# Processing Record 49 of Set 6 | narail
# Processing Record 0 of Set 7 | devinuwara
# City not found. Skipping...
# Processing Record 1 of Set 7 | mogocha
# Processing Record 2 of Set 7 | mount barker
# Processing Record 3 of Set 7 | yemva
# Processing Record 4 of Set 7 | aswan
# Processing Record 5 of Set 7 | nuku'alofa
# Processing Record 6 of Set 7 | monrovia
# Processing Record 7 of Set 7 | as sulayyil
# Processing Record 8 of Set 7 | gloucester
# Processing Record 9 of Set 7 | punta arenas
# Processing Record 10 of Set 7 | conception bay south
# Processing Record 11 of Set 7 | fale old settlement
# Processing Record 12 of Set 7 | mitu
# Processing Record 13 of Set 7 | yangor
# City not found. Skipping...
# Processing Record 14 of Set 7 | prince rupert
# Processing Record 15 of Set 7 | gongdanglegi kulon
# Processing Record 16 of Set 7 | santanyi
# Processing Record 17 of Set 7 | mujiayingzi
# Processing Record 18 of Set 7 | floro
# Processing Record 19 of Set 7 | archangelos
# Processing Record 20 of Set 7 | bayanhongor
# Processing Record 21 of Set 7 | belyy yar
# Processing Record 22 of Set 7 | kalianget
# Processing Record 23 of Set 7 | sao joao do piaui
# Processing Record 24 of Set 7 | buka
# Processing Record 25 of Set 7 | lusaka
# Processing Record 26 of Set 7 | semnan
# Processing Record 27 of Set 7 | brookings
# Processing Record 28 of Set 7 | galle
# Processing Record 29 of Set 7 | antonio enes
# Processing Record 30 of Set 7 | tongging
# Processing Record 31 of Set 7 | vila franca do campo
# Processing Record 32 of Set 7 | lebu
# Processing Record 33 of Set 7 | maumere
# Processing Record 34 of Set 7 | aras-asan
# Processing Record 35 of Set 7 | la peca
# Processing Record 36 of Set 7 | santa cruz
# Processing Record 37 of Set 7 | zindah jan
# Processing Record 38 of Set 7 | quelimane
# Processing Record 39 of Set 7 | alto araguaia
# Processing Record 40 of Set 7 | santa terezinha
# Processing Record 41 of Set 7 | robertsport
# Processing Record 42 of Set 7 | ola
# Processing Record 43 of Set 7 | krasnovishersk
# Processing Record 44 of Set 7 | salekhard
# Processing Record 45 of Set 7 | zag
# Processing Record 46 of Set 7 | mundemba
# Processing Record 47 of Set 7 | maxixe
# Processing Record 48 of Set 7 | manakara
# Processing Record 49 of Set 7 | libreville
# Processing Record 0 of Set 8 | glace bay
# Processing Record 1 of Set 8 | karratha
# Processing Record 2 of Set 8 | mattoon
# Processing Record 3 of Set 8 | port lincoln
# Processing Record 4 of Set 8 | waounde
# Processing Record 5 of Set 8 | bukoba
# Processing Record 6 of Set 8 | baganga
# Processing Record 7 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 8 of Set 8 | saldanha
# Processing Record 9 of Set 8 | lihue
# Processing Record 10 of Set 8 | willmar
# Processing Record 11 of Set 8 | luga
# Processing Record 12 of Set 8 | puerto santa
# Processing Record 13 of Set 8 | cantanhede
# Processing Record 14 of Set 8 | harlan
# Processing Record 15 of Set 8 | igarka
# Processing Record 16 of Set 8 | isle of lewis
# City not found. Skipping...
# Processing Record 17 of Set 8 | kavaratti
# Processing Record 18 of Set 8 | toliara
# Processing Record 19 of Set 8 | unterhausen
# Processing Record 20 of Set 8 | bafia
# Processing Record 21 of Set 8 | genhe
# Processing Record 22 of Set 8 | tabou
# Processing Record 23 of Set 8 | union
# Processing Record 24 of Set 8 | thanh hoa
# Processing Record 25 of Set 8 | mochudi
# Processing Record 26 of Set 8 | san luis de la loma
# Processing Record 27 of Set 8 | kirkwall
# Processing Record 28 of Set 8 | christchurch
# Processing Record 29 of Set 8 | kidal
# Processing Record 30 of Set 8 | botro
# Processing Record 31 of Set 8 | tsiombe
# Processing Record 32 of Set 8 | puerto deseado
# Processing Record 33 of Set 8 | laubach
# Processing Record 34 of Set 8 | nueva gerona
# Processing Record 35 of Set 8 | port macquarie
# Processing Record 36 of Set 8 | golbasi
# Processing Record 37 of Set 8 | dzhangala
# Processing Record 38 of Set 8 | hirara
# Processing Record 39 of Set 8 | oualidia
# City not found. Skipping...
# Processing Record 40 of Set 8 | klaksvik
# Processing Record 41 of Set 8 | pico truncado
# Processing Record 42 of Set 8 | bohmte
# Processing Record 43 of Set 8 | cam ranh
# Processing Record 44 of Set 8 | sillamae
# Processing Record 45 of Set 8 | santa ana de yacuma
# Processing Record 46 of Set 8 | gizo
# Processing Record 47 of Set 8 | fonadhoo
# City not found. Skipping...
# Processing Record 48 of Set 8 | puerto baquerizo moreno
# Processing Record 49 of Set 8 | san pedro pochutla
# Processing Record 0 of Set 9 | swan hill
# Processing Record 1 of Set 9 | sibiti
# Processing Record 2 of Set 9 | sidi ifni
# Processing Record 3 of Set 9 | remire-montjoly
# Processing Record 4 of Set 9 | pontianak
# Processing Record 5 of Set 9 | mboursou lere
# Processing Record 6 of Set 9 | yangju
# Processing Record 7 of Set 9 | nyurba
# Processing Record 8 of Set 9 | gunnison
# Processing Record 9 of Set 9 | auki
# Processing Record 10 of Set 9 | peace river
# Processing Record 11 of Set 9 | hasaki
# Processing Record 12 of Set 9 | kupang
# Processing Record 13 of Set 9 | ixtapa
# Processing Record 14 of Set 9 | maceio
# Processing Record 15 of Set 9 | fort bragg
# Processing Record 16 of Set 9 | port isabel
# Processing Record 17 of Set 9 | murun-kuren
# Processing Record 18 of Set 9 | vylkove
# Processing Record 19 of Set 9 | sept-iles
# Processing Record 20 of Set 9 | carnarvon
# Processing Record 21 of Set 9 | newman
# Processing Record 22 of Set 9 | la reforma
# Processing Record 23 of Set 9 | port douglas
# Processing Record 24 of Set 9 | bayan nur
# City not found. Skipping...
# Processing Record 25 of Set 9 | inarajan village
# Processing Record 26 of Set 9 | misratah
# Processing Record 27 of Set 9 | puerto lempira
# Processing Record 28 of Set 9 | yreka
# Processing Record 29 of Set 9 | funafuti
# Processing Record 30 of Set 9 | maun
# Processing Record 31 of Set 9 | selebi-phikwe
# Processing Record 32 of Set 9 | saint-francois
# Processing Record 33 of Set 9 | mutuali
# Processing Record 34 of Set 9 | horta
# Processing Record 35 of Set 9 | qamdo
# Processing Record 36 of Set 9 | cabugao
# Processing Record 37 of Set 9 | emerald
# Processing Record 38 of Set 9 | nyachera
# Processing Record 39 of Set 9 | hotan
# Processing Record 40 of Set 9 | nuuk
# Processing Record 41 of Set 9 | kotovo
# Processing Record 42 of Set 9 | sinop
# Processing Record 43 of Set 9 | faya-largeau
# Processing Record 44 of Set 9 | rio grande
# Processing Record 45 of Set 9 | kiunga
# Processing Record 46 of Set 9 | recani
# Processing Record 47 of Set 9 | mayya
# Processing Record 48 of Set 9 | villa gesell
# Processing Record 49 of Set 9 | sarmiento
# Processing Record 0 of Set 10 | opuwo
# Processing Record 1 of Set 10 | kruisfontein
# Processing Record 2 of Set 10 | dehloran
# Processing Record 3 of Set 10 | jodhpur
# Processing Record 4 of Set 10 | ishigaki
# Processing Record 5 of Set 10 | freeport
# Processing Record 6 of Set 10 | nafplio
# Processing Record 7 of Set 10 | kill devil hills
# Processing Record 8 of Set 10 | progreso
# Processing Record 9 of Set 10 | seaside
# Processing Record 10 of Set 10 | ikwiriri
# Processing Record 11 of Set 10 | wainwright
# Processing Record 12 of Set 10 | tanabe
# Processing Record 13 of Set 10 | kozelets'
# City not found. Skipping...
# Processing Record 14 of Set 10 | pathein
# Processing Record 15 of Set 10 | sumenep
# Processing Record 16 of Set 10 | zaokskiy
# Processing Record 17 of Set 10 | miri
# Processing Record 18 of Set 10 | listowel
# Processing Record 19 of Set 10 | daru
# Processing Record 20 of Set 10 | popesti
# Processing Record 21 of Set 10 | takamaka
# City not found. Skipping...
# Processing Record 22 of Set 10 | greymouth
# Processing Record 23 of Set 10 | carutapera
# Processing Record 24 of Set 10 | qal'at bishah
# City not found. Skipping...
# Processing Record 25 of Set 10 | polyarnyy
# Processing Record 26 of Set 10 | kerman
# Processing Record 27 of Set 10 | howrah
# Processing Record 28 of Set 10 | angaur state
# Processing Record 29 of Set 10 | korem
# Processing Record 30 of Set 10 | hami
# Processing Record 31 of Set 10 | burang
# Processing Record 32 of Set 10 | coxen hole
# Processing Record 33 of Set 10 | llorente
# Processing Record 34 of Set 10 | lagoa
# Processing Record 35 of Set 10 | cururupu
# Processing Record 36 of Set 10 | am djarass
# City not found. Skipping...
# Processing Record 37 of Set 10 | mbanza-ngungu
# Processing Record 38 of Set 10 | sao jose da coroa grande
# Processing Record 39 of Set 10 | smithers
# Processing Record 40 of Set 10 | tidjikja
# Processing Record 41 of Set 10 | saynshand
# Processing Record 42 of Set 10 | obo
# Processing Record 43 of Set 10 | kuta
# Processing Record 44 of Set 10 | diawara
# Processing Record 45 of Set 10 | mossel bay
# Processing Record 46 of Set 10 | argo
# Processing Record 47 of Set 10 | la'ie
# Processing Record 48 of Set 10 | falmouth
# Processing Record 49 of Set 10 | sadovoye
# Processing Record 0 of Set 11 | kenora
# Processing Record 1 of Set 11 | tyup
# Processing Record 2 of Set 11 | glennville
# Processing Record 3 of Set 11 | juneau
# Processing Record 4 of Set 11 | port blair
# Processing Record 5 of Set 11 | heihe
# Processing Record 6 of Set 11 | akureyri
# Processing Record 7 of Set 11 | kashgar
# Processing Record 8 of Set 11 | yuzhno-kurilsk
# Processing Record 9 of Set 11 | tamandare
# Processing Record 10 of Set 11 | kirensk
# Processing Record 11 of Set 11 | port-gentil
# Processing Record 12 of Set 11 | kichmengskiy gorodok
# Processing Record 13 of Set 11 | tocopilla
# Processing Record 14 of Set 11 | salmon arm
# Processing Record 15 of Set 11 | maturin
# Processing Record 16 of Set 11 | geraldton
# Processing Record 17 of Set 11 | waingapu
# Processing Record 18 of Set 11 | pudasjarvi
# Processing Record 19 of Set 11 | sao desiderio
# Processing Record 20 of Set 11 | valparaiso
# Processing Record 21 of Set 11 | den burg
# Processing Record 22 of Set 11 | amahai
# Processing Record 23 of Set 11 | gueoul
# City not found. Skipping...
# Processing Record 24 of Set 11 | brisas de zicatela
# Processing Record 25 of Set 11 | alo
# Processing Record 26 of Set 11 | recreo
# Processing Record 27 of Set 11 | nampula
# Processing Record 28 of Set 11 | songea
# Processing Record 29 of Set 11 | bereznik
# Processing Record 30 of Set 11 | halberstadt
# Processing Record 31 of Set 11 | nikol'sk
# Processing Record 32 of Set 11 | mancio lima
# Processing Record 33 of Set 11 | bongouanou
# Processing Record 34 of Set 11 | mendoza
# Processing Record 35 of Set 11 | kapa'a
# Processing Record 36 of Set 11 | puerto san carlos
# City not found. Skipping...
# Processing Record 37 of Set 11 | nykoping
# Processing Record 38 of Set 11 | nantucket
# Processing Record 39 of Set 11 | nairn
# Processing Record 40 of Set 11 | braganca
# Processing Record 41 of Set 11 | tindouf
# Processing Record 42 of Set 11 | taesal-li
# Processing Record 43 of Set 11 | tshabong
# Processing Record 44 of Set 11 | dadonghai
# City not found. Skipping...
# Processing Record 45 of Set 11 | kayangel
# Processing Record 46 of Set 11 | doue-la-fontaine
# Processing Record 47 of Set 11 | maua
# Processing Record 48 of Set 11 | lata
# Processing Record 49 of Set 11 | morondava
# Processing Record 0 of Set 12 | basse-terre
# Processing Record 1 of Set 12 | shiyan
# Processing Record 2 of Set 12 | kasongo
# Processing Record 3 of Set 12 | arroio grande
# Processing Record 4 of Set 12 | ahau
# City not found. Skipping...
# Processing Record 5 of Set 12 | duong dong
# Processing Record 6 of Set 12 | krasnyy chikoy
# Processing Record 7 of Set 12 | shimo-furano
# Processing Record 8 of Set 12 | horodnytsya
# Processing Record 9 of Set 12 | atasu
# Processing Record 10 of Set 12 | selfoss
# Processing Record 11 of Set 12 | tamiahua
# Processing Record 12 of Set 12 | gongzhuling
# Processing Record 13 of Set 12 | aykhal
# Processing Record 14 of Set 12 | zhovkva
# Processing Record 15 of Set 12 | saint-hilaire-de-riez
# Processing Record 16 of Set 12 | manokwari
# Processing Record 17 of Set 12 | springfield
# Processing Record 18 of Set 12 | kostomuksha
# Processing Record 19 of Set 12 | cotonou
# Processing Record 20 of Set 12 | rehoboth
# Processing Record 21 of Set 12 | zhelezinka
# Processing Record 22 of Set 12 | beckley
# Processing Record 23 of Set 12 | vikhorevka
# Processing Record 24 of Set 12 | tolanaro
# Processing Record 25 of Set 12 | rabo de peixe
# Processing Record 26 of Set 12 | crane
# Processing Record 27 of Set 12 | gangapur
# Processing Record 28 of Set 12 | abdulino
# Processing Record 29 of Set 12 | palma soriano
# Processing Record 30 of Set 12 | mahina
# Processing Record 31 of Set 12 | sao joao da barra
# Processing Record 32 of Set 12 | chibougamau
# Processing Record 33 of Set 12 | curanilahue
# Processing Record 34 of Set 12 | tympaki
# Processing Record 35 of Set 12 | pallappatti
# Processing Record 36 of Set 12 | coquimbo
# Processing Record 37 of Set 12 | queenstown
# Processing Record 38 of Set 12 | melekeok village
# Processing Record 39 of Set 12 | lubang
# Processing Record 40 of Set 12 | conde
# Processing Record 41 of Set 12 | lauro de freitas
# Processing Record 42 of Set 12 | micheweni
# Processing Record 43 of Set 12 | cable beach
# City not found. Skipping...
# Processing Record 44 of Set 12 | marsabit
# Processing Record 45 of Set 12 | vingt cinq
# City not found. Skipping...
# Processing Record 46 of Set 12 | abeche
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
print(city_data_df.head())
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       tiksi  71.6872  128.8694    270.25        87         100        1.75
# 1   adamstown -25.0660 -130.1015    294.04        74          97        8.02
# 2   sonamukhi  23.3000   87.4167    308.33         7           0        2.59
# 3   grytviken -54.2811  -36.5092    270.75        78          30        3.03
# 4  isafjordur  66.0755  -23.1240    274.82        74          25        1.24
#
#   Country        Date
# 0      RU  1714705146
# 1      PN  1714705146
# 2      IN  1714705146
# 3      GS  1714705146
# 4      IS  1714705146

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       tiksi  71.6872  128.8694    270.25        87         100        1.75
# 1   adamstown -25.0660 -130.1015    294.04        74          97        8.02
# 2   sonamukhi  23.3000   87.4167    308.33         7           0        2.59
# 3   grytviken -54.2811  -36.5092    270.75        78          30        3.03
# 4  isafjordur  66.0755  -23.1240    274.82        74          25        1.24
#
#   Country        Date
# 0      RU  1714705146
# 1      PN  1714705146
# 2      IN  1714705146
# 3      GS  1714705146
# 4      IS  1714705146

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             tiksi  71.6872  128.8694    270.25        87         100
# 1         adamstown -25.0660 -130.1015    294.04        74          97
# 2         sonamukhi  23.3000   87.4167    308.33         7           0
# 3         grytviken -54.2811  -36.5092    270.75        78          30
# 4        isafjordur  66.0755  -23.1240    274.82        74          25
#
#          Wind Speed Country        Date
# City_ID
# 0              1.75      RU  1714705146
# 1              8.02      PN  1714705146
# 2              2.59      IN  1714705146
# 3              3.03      GS  1714705146
# 4              1.24      IS  1714705146

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Create DataFrame from city_data list
city_data_df = pd.DataFrame(city_data)

# Plot scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", edgecolors="black")

# Add labels and title
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°F)")

# Add grid
plt.grid(True)

# Display the plot
plt.show()



# Incorporate the other graph properties
# YOUR CODE HERE


# Create DataFrame from city_data list
city_data_df = pd.DataFrame(city_data)

# Set up the figure size
plt.figure(figsize=(10, 6))

# Plot scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], c=city_data_df["Max Temp"], cmap="coolwarm", 
            edgecolors="black", alpha=0.75)

# Add labels and title
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°F)")

# Add a color bar
cbar = plt.colorbar()
cbar.set_label("Temperature (°F)")

# Add grid
plt.grid(True)

# Save the plot to an image file
plt.savefig("latitude_vs_temperature.png")

# Display the plot
plt.show()



# Define the directory path
directory = "output_data"

# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)
    


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Create scatter plot for latitude vs. humidity
plt.figure(figsize=(10, 6))  # Set up the figure size
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolors="black")

# Add labels and title
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Add grid
plt.grid(True)

# Display the plot
plt.show()



# Create DataFrame from city_data list
city_data_df = pd.DataFrame(city_data)
print(city_data_df.head())




# Set up the figure size
plt.figure(figsize=(10, 6))

# Plot scatter plot for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolors="black")

# Add labels and title
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Add grid
plt.grid(True)

# Display the plot
plt.show()




# Incorporate the other graph properties
# YOUR CODE HERE


# Set up the figure size
plt.figure(figsize=(10, 6))

# Create scatter plot for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], c=city_data_df["Humidity"], cmap="Blues", 
            marker="o", edgecolors="black", alpha=0.75)

# Add labels and title
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Add a color bar
cbar = plt.colorbar()
cbar.set_label("Humidity (%)")

# Add grid
plt.grid(True)

# Save the plot to an image file
plt.savefig("latitude_vs_humidity.png")

# Display the plot
plt.show()




# Create DataFrame from city_data list
city_data_df = pd.DataFrame(city_data)
print(city_data_df.head())



# Set up the figure size
plt.figure(figsize=(10, 6))

# Plot scatter plot for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], c=city_data_df["Humidity"], cmap="Blues", 
            edgecolors="black", alpha=0.75)

# Add labels and title
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Add a color bar
cbar = plt.colorbar()
cbar.set_label("Humidity (%)")

# Add grid
plt.grid(True)

# Display the plot
plt.show()


# Define the directory path
directory = "output_data"

# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)



# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       tiksi  71.6872  128.8694    270.25        87         100        1.75
# 1   adamstown -25.0660 -130.1015    294.04        74          97        8.02
# 2   sonamukhi  23.3000   87.4167    308.33         7           0        2.59
# 3   grytviken -54.2811  -36.5092    270.75        78          30        3.03
# 4  isafjordur  66.0755  -23.1240    274.82        74          25        1.24
#
#   Country        Date
# 0      RU  1714705146
# 1      PN  1714705146
# 2      IN  1714705146
# 3      GS  1714705146
# 4      IS  1714705146
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       tiksi  71.6872  128.8694    270.25        87         100        1.75
# 1   adamstown -25.0660 -130.1015    294.04        74          97        8.02
# 2   sonamukhi  23.3000   87.4167    308.33         7           0        2.59
# 3   grytviken -54.2811  -36.5092    270.75        78          30        3.03
# 4  isafjordur  66.0755  -23.1240    274.82        74          25        1.24
#
#   Country        Date
# 0      RU  1714705146
# 1      PN  1714705146
# 2      IN  1714705146
# 3      GS  1714705146
# 4      IS  1714705146

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Set up the figure size
plt.figure(figsize=(10, 6))

# Create scatter plot for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolors="black")

# Add labels and title
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Add grid
plt.grid(True)

# Display the plot
plt.show()



# Incorporate the other graph properties
# YOUR CODE HERE


# Set up the figure size
plt.figure(figsize=(10, 6))

# Create scatter plot for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], c=city_data_df["Cloudiness"], cmap="Blues", 
            marker="o", edgecolors="black", alpha=0.75)

# Add labels and title
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Add a color bar
cbar = plt.colorbar()
cbar.set_label("Cloudiness (%)")

# Add grid
plt.grid(True)

# Save the plot to an image file
plt.savefig("latitude_vs_cloudiness.png")

# Display the plot
plt.show()



# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)



# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE



# Set up the figure size
plt.figure(figsize=(10, 6))

# Create scatter plot for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", edgecolors="black")

# Add labels and title
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Add grid
plt.grid(True)

# Display the plot
plt.show()




# Incorporate the other graph properties
# YOUR CODE HERE


# Set up the figure size
plt.figure(figsize=(10, 6))

# Create scatter plot for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], c=city_data_df["Wind Speed"], cmap="cool", 
            marker="o", edgecolors="black", alpha=0.75)

# Add labels and title
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Add a color bar
cbar = plt.colorbar()
cbar.set_label("Wind Speed (mph)")

# Add grid
plt.grid(True)

# Save the plot to an image file
plt.savefig("latitude_vs_wind_speed.png")

# Display the plot
plt.show()



# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)



# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE


 # Generate sample data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 3, 4, 5, 6])

# Call the function with the sample data
plot_linear_regression(x, y, 'X-axis Label', 'Y-axis Label', 'Linear Regression Plot')



def plot_linear_regression(x, y, xlabel, ylabel, title, save_file=None):
    
    Create a scatter plot with a linear regression line.
    
    Parameters:
        x (array-like): The data for the x-axis.
        y (array-like): The data for the y-axis.
        xlabel (str): Label for the x-axis.
        ylabel (str): Label for the y-axis.
        title (str): Title for the plot.
        save_file (str, optional): File path to save the plot image. If None, the plot will not be saved.

    Returns:
        None
    ""

    
    # Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)
regression_line = slope * x + intercept
    
# Plot the scatter plot
plt.scatter(x, y, label='Data')
    
# Plot the regression line
plt.plot(x, regression_line, color='red', label='Linear Regression')
    
# Add labels and title
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
    
# Add legend
plt.legend()
    
# Display the plot
plt.show()
# Out:
#   Cell In[35], line 16
#     Create a scatter plot with a linear regression line.
#            ^
# SyntaxError: invalid syntax

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE


# Filter data for Northern Hemisphere (latitude >= 0)
northern_hemisphere_df = city_data_df[city_data_df["Lat"] >= 0]

# Display the DataFrame
print(northern_hemisphere_df.head())
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       tiksi  71.6872  128.8694    270.25        87         100        1.75
# 2   sonamukhi  23.3000   87.4167    308.33         7           0        2.59
# 4  isafjordur  66.0755  -23.1240    274.82        74          25        1.24
# 5   senatobia  34.6176  -89.9687    292.40        90         100        1.79
# 6  porto novo   6.4965    2.6036    303.05        82         100        2.79
#
#   Country        Date
# 0      RU  1714705146
# 2      IN  1714705146
# 4      IS  1714705146
# 5      US  1714704959
# 6      BJ  1714705146

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE


# Filter data for Southern Hemisphere (latitude < 0)
southern_hemisphere_df = city_data_df[city_data_df["Lat"] < 0]

# Display the DataFrame
print(southern_hemisphere_df.head())
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 1   adamstown -25.0660 -130.1015    294.04        74          97        8.02
# 3   grytviken -54.2811  -36.5092    270.75        78          30        3.03
# 8   papatowai -46.5619  169.4708    283.42        80          97        4.61
# 9    coruripe -10.1256  -36.1756    298.16        87          21        2.50
# 11      ancud -41.8697  -73.8203    281.34        79         100        3.85
#
#    Country        Date
# 1       PN  1714705146
# 3       GS  1714705146
# 8       NZ  1714705147
# 9       BR  1714705147
# 11      CL  1714705147

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE


# Filter data for Northern Hemisphere (latitude >= 0)
northern_hemisphere_df = city_data_df[city_data_df["Lat"] >= 0]

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(northern_hemisphere_df["Lat"], northern_hemisphere_df["Max Temp"])

# Plot linear regression
plot_linear_regression(northern_hemisphere_df["Lat"], northern_hemisphere_df["Max Temp"],
                       "Latitude", "Max Temperature (°F)", "Northern Hemisphere - Temperature vs. Latitude",
                       save_file="northern_hemisphere_temp_vs_lat_regression.png")




# Filter data for Northern Hemisphere (latitude >= 0)
northern_hemisphere_df = city_data_df[city_data_df["Lat"] >= 0]

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(northern_hemisphere_df["Lat"], northern_hemisphere_df["Max Temp"])

# Print regression parameters
print("Slope:", slope)
print("Intercept:", intercept)
print("R-value:", r_value)
print("P-value:", p_value)
print("Standard error:", std_err)
# Out:
# Slope: -0.5015838138953257
# Intercept: 307.15493802172523
# R-value: -0.8742724851240034
# P-value: 3.988892399779252e-119
# Standard error: 0.01442028412352729

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE


# Filter data for Southern Hemisphere (latitude < 0)
southern_hemisphere_df = city_data_df[city_data_df["Lat"] < 0]

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(southern_hemisphere_df["Lat"], southern_hemisphere_df["Max Temp"])

# Plot linear regression
plot_linear_regression(southern_hemisphere_df["Lat"], southern_hemisphere_df["Max Temp"],
                       "Latitude", "Max Temperature (°F)", "Southern Hemisphere - Temperature vs. Latitude",
                       save_file="southern_hemisphere_temp_vs_lat_regression.png")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
#
# Looking at the plots, it appears that the Temperature and Lattitude are inversly related between the Norther and Souther Hemisphere's.
# For example, in the Northern Hemisphere, as the Latitude increases from 0 to 80, the Temperature decreases from ~310F to ~265F.
# On the other hand, in the Southner Hemisphere, as the Latitude increases from -50 to 0, the Temperature increases from ~280F to ~305
# An assessment of the R-value indicates strong correlation between Temperature and Latitude, and the p-value indicates that the correlation is statistically significant.F.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# Filter data for Northern Hemisphere (latitude >= 0)
northern_hemisphere_df = city_data_df[city_data_df["Lat"] >= 0]

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(northern_hemisphere_df["Lat"], northern_hemisphere_df["Humidity"])

# Plot linear regression
plot_linear_regression(northern_hemisphere_df["Lat"], northern_hemisphere_df["Humidity"],
                       "Latitude", "Humidity (%)", "Northern Hemisphere - Humidity vs. Latitude",
                       save_file="northern_hemisphere_humidity_vs_lat_regression.png")

# Determine correlation and statistical significance
print("Correlation and Statistical Significance:")
print("R-value:", r_value)
print("P-value:", p_value)
print("Standard error:", std_err)
# Out:
# Correlation and Statistical Significance:
# R-value: 0.08612339044672701
# P-value: 0.095852943136087
# Standard error: 0.06239631273569434

# %%
# Southern Hemisphere
# YOUR CODE HERE

# Filter data for Southern Hemisphere (latitude < 0)
southern_hemisphere_df = city_data_df[city_data_df["Lat"] < 0]

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(southern_hemisphere_df["Lat"], southern_hemisphere_df["Humidity"])

# Plot linear regression
plot_linear_regression(southern_hemisphere_df["Lat"], southern_hemisphere_df["Humidity"],
                       "Latitude", "Humidity (%)", "Southern Hemisphere - Humidity vs. Latitude",
                       save_file="southern_hemisphere_humidity_vs_lat_regression.png")

# Filter data for Southern Hemisphere (latitude < 0)
southern_hemisphere_df = city_data_df[city_data_df["Lat"] < 0]

# Determine correlation and statistical significance
print("Correlation and Statistical Significance:")
print("R-value:", r_value)
print("P-value:", p_value)
print("Standard error:", std_err)
# Out:
# Correlation and Statistical Significance:
# R-value: 0.31408979496764683
# P-value: 1.756667351178137e-05
# Standard error: 0.08800262023694772

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
# Since the R-values (Correlation Coefficient) for both Northern and Southern Hemispheres relative to Humidity and Latitude are both close to zero,
# being (0.21 and 0.02) respectively, there is a very weak to weak positive correlation. For the Northern Hemisphere, as latitude increases, humidity increases slightly.  On the other hand, the p-value (1.02 x 10E-5) for the Nothern Hemisphere is significantly less then 0.05, indicating that the relationship between humidity and latitude in the Northern Hemisphere is statistically significant. The relationship between humidity and latitude in the Southern Hemisphere is not statistically significant.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE


# Filter data for Northern Hemisphere (latitude >= 0)
northern_hemisphere_df = city_data_df[city_data_df["Lat"] >= 0]

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(northern_hemisphere_df["Lat"], northern_hemisphere_df["Cloudiness"])

# Plot linear regression
plot_linear_regression(northern_hemisphere_df["Lat"], northern_hemisphere_df["Cloudiness"],
                       "Latitude", "Cloudiness (%)", "Northern Hemisphere - Cloudiness vs. Latitude",
                       save_file="northern_hemisphere_cloudiness_vs_lat_regression.png")

# Determine correlation and statistical significance
print("Correlation and Statistical Significance:")
print("R-value:", r_value)
print("P-value:", p_value)
print("Standard error:", std_err)
# Out:
# Correlation and Statistical Significance:
# R-value: 0.0734758684155563
# P-value: 0.1556007050943894
# Standard error: 0.10482287409652755

# %%
# Southern Hemisphere
# YOUR CODE HERE


# Filter data for Southern Hemisphere (latitude < 0)
southern_hemisphere_df = city_data_df[city_data_df["Lat"] < 0]

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(southern_hemisphere_df["Lat"], southern_hemisphere_df["Cloudiness"])

# Plot linear regression
plot_linear_regression(southern_hemisphere_df["Lat"], southern_hemisphere_df["Cloudiness"],
                       "Latitude", "Cloudiness (%)", "Southern Hemisphere - Cloudiness vs. Latitude",
                       save_file="southern_hemisphere_cloudiness_vs_lat_regression.png")

# Determine correlation and statistical significance
print("Correlation and Statistical Significance:")
print("R-value:", r_value)
print("P-value:", p_value)
print("Standard error:", std_err)
# Out:
# Correlation and Statistical Significance:
# R-value: 0.21983171391810669
# P-value: 0.003025220075638362
# Standard error: 0.20251129528104644

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
#
# The 0.068 R-value between Cloudiness and Latitude indicates a very weak positive correlation in the Northern Hemisphere.  Since the p-value is significantly less then 0.05, the relationship between Cloudiness and Latitude is significantly different.  With regards to the Southern Hemisphere,
# there is a weak positive correlation between Cloudiness and Latitude. The very small p-value (0.004) indicates a statitically significant difference
# between Cloudiness and Latitude in the Southern Hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# Filter data for Northern Hemisphere (latitude >= 0)
northern_hemisphere_df = city_data_df[city_data_df["Lat"] >= 0]

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(northern_hemisphere_df["Lat"], northern_hemisphere_df["Wind Speed"])

# Plot linear regression
plot_linear_regression(northern_hemisphere_df["Lat"], northern_hemisphere_df["Wind Speed"],
                       "Latitude", "Wind Speed (mph)", "Northern Hemisphere - Wind Speed vs. Latitude",
                       save_file="northern_hemisphere_wind_speed_vs_lat_regression.png")

# Determine correlation and statistical significance
print("Correlation and Statistical Significance:")
print("R-value:", r_value)
print("P-value:", p_value)
print("Standard error:", std_err)
# Out:
# Correlation and Statistical Significance:
# R-value: -0.025380950313484574
# P-value: 0.6241777204792602
# Standard error: 0.005521828167162615

# %%
# Southern Hemisphere
# YOUR CODE HERE

# Filter data for Southern Hemisphere (latitude < 0)
southern_hemisphere_df = city_data_df[city_data_df["Lat"] < 0]

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(southern_hemisphere_df["Lat"], southern_hemisphere_df["Wind Speed"])

# Plot linear regression
plot_linear_regression(southern_hemisphere_df["Lat"], southern_hemisphere_df["Wind Speed"],
                       "Latitude", "Wind Speed (mph)", "Southern Hemisphere - Wind Speed vs. Latitude",
                       save_file="southern_hemisphere_wind_speed_vs_lat_regression.png")

# Determine correlation and statistical significance
print("Correlation and Statistical Significance:")
print("R-value:", r_value)
print("P-value:", p_value)
print("Standard error:", std_err)
# Out:
# Correlation and Statistical Significance:
# R-value: -0.13276664678297476
# P-value: 0.07561501073445978
# Standard error: 0.013095317473713395

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
# The very small R-value (-0.06) being very close to zero indicates a very weak negative correlation between wind speed and latitude in the Northern Hemisphere. The 0.215 p-value is significantly larger then 0.05 indicates that the relationship between wind speed and latitude in the Northern Hemisphere is not statistically significant.  With regard to the Southern Hemisphere, the -0.246 R-value indicates a weak negative correlation between wind speed and latitude in the Southern Hemisphere, and the 0.0009 p-value being much smaller then 0.05 indicates that the relationship between wind speed and latitude in the Southern Hemisphere is statistically significant.
